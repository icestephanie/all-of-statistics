# %% [markdown]
# **Exercise 5.6.1**.  Let $X \sim \text{Exponential}(\beta)$.  Find $\mathbb{P}(|X - \mu_X| > k \sigma_X)$ for $k > 1$.  Compare this to the bound you get from Chebyshev's inequality.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def f(k):
    return np.where(k>0, 1+np.exp(-np.maximum(1+k,0))-np.exp(-np.maximum(1-k,0)), 1-np.exp(-np.maximum(1+k,0))+np.exp(-np.maximum(1-k,0)))

def chebyshev(k):
    return np.minimum(1/(k**2),1)

kk=np.arange(0.01,10,step=0.01)
                    
plt.figure(figsize=(12,8))
                    
plt.plot(kk,f(kk), label='calculated probability')
plt.plot(kk,chebyshev(kk),label='Chebyshev bound')
plt.legend(loc='lower left')
plt.yscale('log')
plt.xlabel('k')
plt.ylabel('probability bound')
plt.show()

# %% [markdown]
# **Exercise 5.6.4**.  Let $X_1, \dots, X_n \sim \text{Bernoulli}(p)$.
#
# **(a)**  Let $\alpha > 0$ be fixed and define
#
# $$ \epsilon_n = \sqrt{\frac{1}{2n} \log \left( \frac{2}{\alpha}\right)} $$
#
# Let $\hat{p}_n = n^{-1} \sum_{i=1}^n X_i$.  Define $C_n = (\hat{p}_n - \epsilon_n, \hat{p}_n + \epsilon_n)$.  Use Hoeffding's inequality to show that
#
# $$ \mathbb{P}(p \in C_n) \geq 1 - \alpha $$
#
# We call $C_n$ a *$1 - \alpha$ confidence interval for $p$*. In practice, we truncate the interval so it does not go below 0 or above 1.
#
# **(b) (Computer Experiment)** Let's examine the properties of this confidence interval.  Let $\alpha = 0.05$ and $p = 0.4$.  Conduct a simulation study to see how often the interval contains $p$ (called the coverage).  Do this for various values of $n$ between 1 and 10000.  Plot the coverage versus $n$.
#
# **(c)** Plot the length of the interval versus $n$.  Suppose we want the length of the interval to be no more than .05.  How large should $n$ be?

# %%
import numpy as np
from scipy.stats import bernoulli
from tqdm.notebook import tqdm

alpha=0.05
p=0.4

B=50000
N=10000

nn=np.arange(1,N+1)
epsilon_n=np.sqrt((1/(2*nn))*np.log(2/alpha))

p_hat=np.empty((B,N))
for i in tqdm(range(B)):
    X=bernoulli.rvs(p, size=N, random_state=i)
    p_hat[i]=np.cumsum(X)/nn
    
coverage=np.mean((p_hat+epsilon_n>=p) & (p_hat-epsilon_n<=p), axis=0)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50000.0), HTML(value='')))

# %%
import numpy as np
from scipy.stats import bernoulli
from tqdm.notebook import tqdm

alpha=0.05
p=0.4

B=50000
N=10000

nn=np.arange(1,N+1)
epsilon_n=np.sqrt((1/(2*nn))*np.log(2/alpha))


X=np.cumsum(bernoulli.rvs(p, size=(B,N), random_state=np.random.randint(low=0, high=N)),axis=1)
p_hat=X.mean()
    
coverage=np.mean((p_hat+epsilon_n>=p) & (p_hat-epsilon_n<=p), axis=0)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# <ipython-input-37-ac29bb44472c>:16: RuntimeWarning: Mean of empty slice.
#   X=bernoulli.rvs(p, size=(B,i), random_state=i).mean(axis=1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-ac29bb44472c> in <module>
#      14 p_hat=np.empty(N)
#      15 for i in tqdm(range(N)):
# ---> 16     X=bernoulli.rvs(p, size=(B,i), random_state=i).mean(axis=1)
#      17     p_hat[i]=X.mean()
#      18
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwargs)
#    2995         """
#    2996         kwargs['discrete'] = True
# -> 2997         return super(rv_discrete, self).rvs(*args, **kwargs)
#    2998
#    2999     def pmf(self, k, *args, **kwds):
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwds)
#    1002             vals = self._rvs(*args)
#    1003         else:
# -> 1004             vals = self._rvs(*args, size=size, random_state=random_state)
#    1005
#    1006         vals = vals * scale + loc
#
# ~\anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py in _rvs(self, p, size, random_state)
#     115     """
#     116     def _rvs(self, p, size=None, random_state=None):
# --> 117         return binom_gen._rvs(self, 1, p, size=size, random_state=random_state)
#     118
#     119     def _argcheck(self, p):
#
# ~\anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py in _rvs(self, n, p, size, random_state)
#      39     """
#      40     def _rvs(self, n, p, size=None, random_state=None):
# ---> 41         return random_state.binomial(n, p, size)
#      42
#      43     def _argcheck(self, n, p):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(nn, coverage)
plt.xlabel('n')
plt.ylabel('coverage')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(nn, 2*epsilon_n, label='interval length')
plt.xlabel('n')
plt.ylabel(r'$2\epsilon_n$')
plt.hlines(0.05, xmin=0, xmax=N, color='red', label='threshold')
plt.yscale('log')
plt.legend(loc='upper right')
plt.show()

# %%
selected_n=nn[np.argmax(2*epsilon_n<=0.05)]
print('smallest n with interval length under .05: %i' % selected_n)
# Out:
# smallest n with interval length under .05: 2952
